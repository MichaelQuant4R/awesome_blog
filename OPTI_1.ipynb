# %% [markdown]
# # OPTIMIZE JUPYTER NOTEBOOK

# %%
import matplotlib.pyplot as plt
import random as rd


data = rd.sample(range(0, 100), k= 50)
plt.figure(figsize=(12, 8))
plt.plot(data)
plt.show()

# %% [markdown]
# ## Plot description here
# - This is a cool plot!
# - Check out my super plot!!

# %% [markdown]
# # OPTIMIZATION PART 2

# %%
class A:
    
    def __init__(self, a, b):
        
        self.a = a
        self.b = b
        
    def run(self):
        
        print("This is A class!")
